# %% [markdown]
# ## Turning RSS Feeds into HTML with Python
#
# Learn how to fetch RSS feed data, parse it with Python's built-in libraries or third-party tools, and transform it into a clean, functional HTML layout.

# %% [markdown]
# Mastodon, the decentralized microblogging platform, offers RSS feed updates for every account, making it easy to stay updated. For example, the RSS feed for my Mastodon profile, found at https://fosstodon.org/@seve_py, can be accessed simply by adding .rss to the end of the profile URL: https://fosstodon.org/@seve_py.rss.
#
# For a more detailed guide, check out the [full blog post here](https://tessarinseve.pythonanywhere.com/nws/2022-11-19.wiki.html).

# %%
import requests
import xml.etree.ElementTree as ET

# Fetching the RSS feed
url = "https://fosstodon.org/@seve_py.rss"
resp = requests.get(url)
root = ET.fromstring(resp.content)

# Extracting feed items
feed_items = []
for item in root.findall('.//item'):
    feed_item = {
        'description': item.find('description').text,
        'link': item.find('link').text,
        'pubDate': item.find('pubDate').text
    }
    feed_items.append(feed_item)

# Building the HTML structure
html = []
html.append("""
<html>
<head>
    <title>Feed Items</title>
</head>
<body>
""")
template = """
<h2 class='title'>
    <a class='link' href='{link}'>{link}</a>
</h2>
<span class='description'>Description: {description}</span>
<br>
"""

for i in feed_items:
    html.append(template.format(link=i["link"], description=i["description"]))

html.append("""
</body>
</html>
""")

# Joining HTML parts into a single string
final_html = ''.join(html)

# Outputting the HTML (printing or saving to a file)
# print(final_html)

# %%
from IPython.display import  HTML
HTML(final_html)
# Out:
# <html>
# <head>
#     <title>Feed Items</title>
# </head>
# <body>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114161741629720313'>https://fosstodon.org/@seve_py/114161741629720313</a>
# </h2>
# <span class='description'>Description: <p>Celebrate π with a pie! 🥧 Whether it&#39;s sweet or savory, let&#39;s indulge in some deliciousness while we appreciate the beauty of math. Happy Pi Day! <a href="https://fosstodon.org/tags/PiDay" class="mention hashtag" rel="tag">#<span>PiDay</span></a> <br /><a href="https://temu.to/k/ebnm1rvxtxe" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">temu.to/k/ebnm1rvxtxe</span><span class="invisible"></span></a> via @shoptemu <a href="https://pin.it/1DQVOP6jM" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">pin.it/1DQVOP6jM</span><span class="invisible"></span></a> via @pinterest</p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114154553440919350'>https://fosstodon.org/@seve_py/114154553440919350</a>
# </h2>
# <span class='description'>Description: <p>I use <a href="https://fosstodon.org/tags/vim" class="mention hashtag" rel="tag">#<span>vim</span></a> btw</p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114131401035672665'>https://fosstodon.org/@seve_py/114131401035672665</a>
# </h2>
# <span class='description'>Description: <p>Can You Fit Your Entire Personal Knowledge Management System into a Notebook?<br />We think yes! This index card notebook has 8 subsections, each with 20 index cards that can accommodate a 8-custom category framework. <br /><a href="https://fosstodon.org/tags/PersonalKnowledgeManagement" class="mention hashtag" rel="tag">#<span>PersonalKnowledgeManagement</span></a> <a href="https://fosstodon.org/tags/PKM" class="mention hashtag" rel="tag">#<span>PKM</span></a> <a href="https://fosstodon.org/tags/IndexCards" class="mention hashtag" rel="tag">#<span>IndexCards</span></a> <a href="https://fosstodon.org/tags/KnowledgeOrganization" class="mention hashtag" rel="tag">#<span>KnowledgeOrganization</span></a> <a href="https://fosstodon.org/tags/Productivity" class="mention hashtag" rel="tag">#<span>Productivity</span></a>  <a href="https://pin.it/3W0Syf9DX" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">pin.it/3W0Syf9DX</span><span class="invisible"></span></a> via @pinterest</p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114092378770232510'>https://fosstodon.org/@seve_py/114092378770232510</a>
# </h2>
# <span class='description'>Description: <p>Imagine it’s the beginning of March and you don’t have a weekly planner at hand. Which option best describes your preference?<br /><a href="https://fosstodon.org/tags/WeeklyPlanner" class="mention hashtag" rel="tag">#<span>WeeklyPlanner</span></a> <a href="https://fosstodon.org/tags/Productivity" class="mention hashtag" rel="tag">#<span>Productivity</span></a> <a href="https://fosstodon.org/tags/UndatedPlanner" class="mention hashtag" rel="tag">#<span>UndatedPlanner</span></a> <a href="https://fosstodon.org/tags/Organization" class="mention hashtag" rel="tag">#<span>Organization</span></a> <a href="https://fosstodon.org/tags/TimeManagement" class="mention hashtag" rel="tag">#<span>TimeManagement</span></a></p><p><radio disabled="disabled">I don’t use paper planners at all</radio><br><radio disabled="disabled">I want one, but I’m hesitant about losing 2 months</radio><br><radio disabled="disabled">I want one, and I’m ok with losing 2 months</radio><br><radio disabled="disabled">I prefer an undated planner</radio></p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114089080792427415'>https://fosstodon.org/@seve_py/114089080792427415</a>
# </h2>
# <span class='description'>Description: <p>ePub derived from a specialized Anki deck with integrated Python REPL, focusing on the Python Standard Library.  <a href="https://pin.it/6vMDXKvoj" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">pin.it/6vMDXKvoj</span><span class="invisible"></span></a> via @pinterest <br /><a href="https://fosstodon.org/tags/epub" class="mention hashtag" rel="tag">#<span>epub</span></a> <a href="https://fosstodon.org/tags/ebook" class="mention hashtag" rel="tag">#<span>ebook</span></a> <a href="https://fosstodon.org/tags/python" class="mention hashtag" rel="tag">#<span>python</span></a> <a href="https://fosstodon.org/tags/anki" class="mention hashtag" rel="tag">#<span>anki</span></a> <a href="https://fosstodon.org/tags/stdlib" class="mention hashtag" rel="tag">#<span>stdlib</span></a></p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114064773928741021'>https://fosstodon.org/@seve_py/114064773928741021</a>
# </h2>
# <span class='description'>Description: <p>Vim TermDebug Plugin <a href="https://pin.it/6yhbK6EvO" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">pin.it/6yhbK6EvO</span><span class="invisible"></span></a> via @pinterest <br /><a href="https://fosstodon.org/tags/vim" class="mention hashtag" rel="tag">#<span>vim</span></a> <a href="https://fosstodon.org/tags/termdebug" class="mention hashtag" rel="tag">#<span>termdebug</span></a> <a href="https://fosstodon.org/tags/c" class="mention hashtag" rel="tag">#<span>c</span></a>++ <a href="https://fosstodon.org/tags/make" class="mention hashtag" rel="tag">#<span>make</span></a></p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/114025474878141005'>https://fosstodon.org/@seve_py/114025474878141005</a>
# </h2>
# <span class='description'>Description: <p>Don&#39;t forget to check out this growing list of verified promo codes—you might just unlock incredible savings!<br /><a href="https://fosstodon.org/tags/PromoCodes" class="mention hashtag" rel="tag">#<span>PromoCodes</span></a> <a href="https://fosstodon.org/tags/Savings" class="mention hashtag" rel="tag">#<span>Savings</span></a> <a href="https://fosstodon.org/tags/OnlineShopping" class="mention hashtag" rel="tag">#<span>OnlineShopping</span></a> <a href="https://fosstodon.org/tags/ShopSmart" class="mention hashtag" rel="tag">#<span>ShopSmart</span></a>   <a href="https://fosstodon.org/tags/VerifiedCodes" class="mention hashtag" rel="tag">#<span>VerifiedCodes</span></a> <a href="https://fosstodon.org/tags/ShopAndSave" class="mention hashtag" rel="tag">#<span>ShopAndSave</span></a> <a href="https://fosstodon.org/tags/IncredibleSavings" class="mention hashtag" rel="tag">#<span>IncredibleSavings</span></a> <a href="https://pin.it/5STlyZdnm" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">pin.it/5STlyZdnm</span><span class="invisible"></span></a> via @pinterest</p></span>
# <br>
#
# <h2 class='title'>
#     <a class='link' href='https://fosstodon.org/@seve_py/113986594063277021'>https://fosstodon.org/@seve_py/113986594063277021</a>
# </h2>
# <span class='description'>Description: <p>This series of AI-generated dialogues offers tech enthusiasts valuable insights, practical tips, and engaging discussions on various digital topics.  <br /><a href="https://fosstodon.org/tags/TechTalk" class="mention hashtag" rel="tag">#<span>TechTalk</span></a> <a href="https://fosstodon.org/tags/Python" class="mention hashtag" rel="tag">#<span>Python</span></a> <a href="https://fosstodon.org/tags/PythonProgramming" class="mention hashtag" rel="tag">#<span>PythonProgramming</span></a> <a href="https://fosstodon.org/tags/Vim" class="mention hashtag" rel="tag">#<span>Vim</span></a> <a href="https://fosstodon.org/tags/TechEnthusiasts" class="mention hash
